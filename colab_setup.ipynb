# %% [markdown]
# # 🧠 Run BraTS Inference on Colab
#
# Use this notebook to run the Gradio application.

# %% [markdown]
# ### 1. Upload Files
# Please upload the following files to the Colab runtime (Files tab on the left):
# - `app.py`
# - `inference.py`
# - `requirements.txt`

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Run the App
# This will generate a public URL (e.g., https://xxxxx.gradio.live)
# !python app.py
